# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaunakSen/Deep-Learning/blob/master/seven_part_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Sequence Modelling

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer

# %% [markdown]
# ## Markov chains
#
# We'll start our exploration of modelling sequences and building generative models using a 1st order Markov chain. The Markov chain is a stochastic model describing a sequence of possible events in which the probability of each event depends only on the state attained in the previous event. In our case we're going to learn a model over a set of characters from an English language text. The events, or states, in our model are the set of possible characters, and we'll learn the probability of moving from one character to the next.
#
# Let's start by loading the data from the web:

# %%
from torchvision.datasets.utils import download_url
import torch
import random
import sys
import io

# Read the data
download_url('https://s3.amazonaws.com/text-datasets/nietzsche.txt', '.', 'nietzsche.txt', None)
text = io.open('./nietzsche.txt', encoding='utf-8').read().lower()
print('corpus length:', len(text))
# Out:
# Using downloaded and verified file: ./nietzsche.txt
# corpus length: 600893

# %% [markdown]
# We now need to iterate over the characters in the text and count the times each transition happens:

# %%
transition_counts = dict()
for i in range(0,len(text)-1):
    currc = text[i]
    nextc = text[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1

# %%
print (transition_counts)
# Out:
# {'p': {'r': 1533, 'p': 421, 'o': 1259, 'e': 1901, 'h': 778, 'a': 822, '.': 10, 'i': 632, 'u': 314, 's': 321, 'l': 790, 't': 417, ',': 31, ' ': 157, 'y': 23, '\n': 13, 'n': 6, 'm': 30, '?': 1, 'w': 5, 'b': 1, 'f': 7, 'g': 1, '"': 2, ';': 2, '-': 4, ':': 3}, 'r': {'e': 7222, 'u': 562, 'o': 1987, ' ': 4027, 's': 1337, 'r': 325, 'i': 2450, 't': 1289, '\n': 362, 'y': 997, 'a': 2279, 'h': 210, 'm': 552, 'd': 797, ',': 501, 'w': 52, 'l': 337, 'v': 170, '-': 141, 'c': 274, 'p': 158, 'n': 434, '?': 24, 'f': 141, '.': 111, 'g': 130, 'k': 116, ')': 10, '!': 15, ':': 35, ';': 25, 'b': 83, '"': 25, "'": 33, '_': 6, '[': 2, ']': 3, 'x': 1, '=': 1}, 'e': {'f': 641, '\n': 1571, 'n': 5574, 'r': 7885, ' ': 15665, 'c': 1468, 'y': 555, 'e': 1334, 'd': 3223, 's': 5421, 'i': 857, 'm': 1311, 't': 1348, 'v': 1566, 'l': 2885, ',': 1417, 'a': 2590, 'g': 417, 'p': 569, '.': 374, '-': 270, 'u': 153, 'o': 231, '"': 89, 'x': 756, 'w': 342, 'j': 30, '?': 79, 'z': 5, ';': 92, '!': 69, 'h': 97, '_': 11, 'b': 120, 'q': 249, ':': 109, ')': 41, "'": 104, 'k': 69, ']': 7, 'ë': 1}, 'f': {'a': 687, 'o': 1771, ' ': 4906, ',': 126, 'f': 434, 'e': 992, 'i': 867, ')': 4, 't': 208, 'u': 528, '.': 59, 'r': 741, '\n': 438, '-': 148, '"': 10, 'l': 210, ':': 14, '!': 8, 'n': 3, 'y': 40, ';': 13, '?': 7, 's': 3, "'": 1, ']': 4}, 'a': {'c': 1356, 't': 5417, ' ': 1949, 'n': 8547, 'l': 4251, 'r': 3236, 's': 3564, 'v': 708, 'i': 1252, 'd': 993, 'g': 633, 'y': 922, 'k': 472, 'b': 813, 'p': 756, 'm': 747, 'u': 420, 'f': 163, 'w': 178, ',': 40, '\n': 197, 'z': 24, 'x': 28, 'o': 20, '.': 18, '-': 16, "'": 2, 'j': 16, 'h': 13, 'e': 27, ':': 2, 'a': 2, ')': 4, '!': 1, ';': 1, '"': 3, 'q': 1, '_': 3, '[': 1}, 'c': {'e': 2612, 't': 1449, 'l': 348, 'h': 2208, 'o': 2329, 'i': 1139, 'a': 1573, 'u': 429, 'r': 456, ' ': 267, 'k': 226, 'c': 297, '\n': 38, 's': 68, 'y': 105, '-': 9, "'": 6, ',': 36, 'q': 28, 'n': 2, '.': 15, '"': 3, '?': 2, ')': 4, ';': 4, ':': 1, ']': 1}, '\n': {'\n': 898, 's': 638, 'f': 317, 'd': 304, 't': 1120, 'w': 439, 'a': 910, 'i': 655, 'h': 370, '(': 32, 'e': 338, 'p': 425, 'b': 267, 'l': 157, 'c': 430, 'm': 376, 'y': 21, 'o': 516, 'u': 114, 'g': 151, 'n': 195, 'k': 38, '1': 168, 'q': 15, 'r': 240, 'v': 79, '2': 121, "'": 2, '"': 125, '3': 24, '4': 23, 'j': 26, '5': 23, '6': 24, '7': 24, '8': 23, '9': 22, ' ': 117, '[': 25, '-': 1, '=': 137, '_': 4}, 's': {'u': 1277, 'i': 1943, ' ': 10897, 'p': 877, 'o': 1973, ',': 1519, 't': 4597, 'e': 4028, 'n': 84, 's': 1705, 'y': 254, 'k': 124, 'h': 816, 'a': 809, 'c': 661, 'l': 198, 'm': 263, '.': 471, '\n': 990, ':': 129, '"': 95, 'q': 18, '-': 185, '?': 76, '!': 90, 'd': 29, ')': 54, ';': 128, "'": 5, 'b': 6, 'g': 37, 'w': 54, 'f': 76, 'r': 10, 'v': 3, '_': 5, ']': 12, '[': 1, '=': 1}, 'u': {'p': 527, 't': 1536, 'n': 1426, 's': 2130, 'm': 440, 'a': 565, 'r': 1992, 'e': 615, 'f': 122, 'c': 700, 'l': 1522, 'b': 241, 'd': 301, 'g': 526, 'i': 365, 'o': 44, ' ': 98, ':': 1, 'j': 1, 'u': 5, 'x': 13, ',': 14, '\n': 15, 'v': 4, 'z': 4, "'": 2, 'y': 2, '?': 5, '.': 1, 'h': 1, '!': 2, 'k': 1}, 'o': {'s': 1420, 'm': 1903, 't': 1656, 'u': 3502, 'r': 4541, 'p': 980, ' ': 4176, 'g': 324, 'd': 728, 'w': 1515, 'n': 6283, 'f': 4863, 'o': 768, 'l': 1021, 'b': 379, '-': 55, 'i': 251, '\n': 364, ':': 7, 'c': 380, "'": 11, 'y': 93, 'k': 183, '?': 10, ',': 156, 'a': 90, 'e': 265, 'v': 550, 'z': 8, 'h': 18, '.': 30, '!': 15, '"': 2, ';': 3, ')': 3, 'x': 29, 'q': 5, 'j': 2, ']': 2}, 'i': {'n': 9384, 's': 5423, 'l': 1812, 'b': 343, 'o': 2895, 'm': 1498, 't': 5328, 'c': 2588, 'd': 828, 'r': 1363, 'e': 1341, 'f': 918, 'z': 193, 'v': 981, 'a': 706, 'g': 1096, 'q': 18, 'u': 66, '.': 11, 'p': 164, '\n': 15, ' ': 275, 'k': 186, 'i': 11, 'h': 11, 'x': 36, '-': 24, '_': 3, '"': 6, ',': 19, 'w': 1, ')': 2, '?': 2, ':': 1}, 'n': {'g': 3725, '-': 154, '?': 35, 'o': 2220, 'd': 6044, ' ': 6878, '\n': 593, 'e': 3026, 'i': 1042, 's': 2116, 'n': 277, 'l': 386, ';': 56, 't': 3183, ',': 710, 'a': 1190, 'c': 1946, 'y': 386, 'f': 221, 'v': 168, 'j': 104, ':': 73, 'b': 11,  ...

# %% [markdown]
# The `transition_counts` dictionary maps the current character to the next character, and this is then mapped to a count. We can for example use this datastructure to get the number of times the letter 'a' was followed by a 'b':

# %%
print("Number of transitions from 'a' to 'b': " + str(transition_counts['a']['b']))
# Out:
# Number of transitions from 'a' to 'b': 813

# %% [markdown]
# Finally, to complete the model we need to normalise the counts for each initial character into a probability distribution over the possible next character. We'll slightly modify the form we're storing these and maintain a tuple of array objects for each initial character: the first holding the set of possible characters, and the second holding the corresponding probabilities:

# %%
transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    # next_counts is the dict of all transition chars
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    # normalize
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)
        
print(transition_probabilities)
# Out:
# {'p': (['r', 'p', 'o', 'e', 'h', 'a', '.', 'i', 'u', 's', 'l', 't', ',', ' ', 'y', '\n', 'n', 'm', '?', 'w', 'b', 'f', 'g', '"', ';', '-', ':'], [0.16164065795023197, 0.044390552509489666, 0.1327498945592577, 0.20044285111767188, 0.08203289751159848, 0.08667229017292281, 0.001054407423028258, 0.06663854913538592, 0.03310839308308731, 0.03384647827920709, 0.0832981864192324, 0.043968789540278365, 0.0032686630113876003, 0.016554196541543654, 0.002425137072964994, 0.0013707296499367355, 0.0006326444538169548, 0.0031632222690847742, 0.00010544074230282581, 0.000527203711514129, 0.00010544074230282581, 0.0007380851961197807, 0.00010544074230282581, 0.00021088148460565162, 0.00021088148460565162, 0.00042176296921130323, 0.0003163222269084774]), 'r': (['e', 'u', 'o', ' ', 's', 'r', 'i', 't', '\n', 'y', 'a', 'h', 'm', 'd', ',', 'w', 'l', 'v', '-', 'c', 'p', 'n', '?', 'f', '.', 'g', 'k', ')', '!', ':', ';', 'b', '"', "'", '_', '[', ']', 'x', '='], [0.26528063473405816, 0.020643549808992065, 0.07298707023214811, 0.14792095210108727, 0.04911107846018219, 0.011937995885982957, 0.08999412283279459, 0.04734792829856009, 0.013297090802233324, 0.03662209814869233, 0.08371290038201587, 0.007713781957096679, 0.02027622685865413, 0.02927563914193359, 0.018402879811930648, 0.001910079341757273, 0.012378783426388481, 0.006244490155744931, 0.005179253599764913, 0.010064648839259477, 0.005803702615339406, 0.01594181604466647, 0.000881575080811049, 0.005179253599764913, 0.004077284748751102, 0.004775198354393183, 0.004260946223920071, 0.0003673229503379371, 0.0005509844255069057, 0.0012856303261827799, 0.0009183073758448428, 0.003048780487804878, 0.0009183073758448428, 0.0012121657361151925, 0.00022039377020276226, 7.346459006758743e-05, 0.00011019688510138113, 3.6732295033793715e-05, 3.6732295033793715e-05]), 'e': (['f', '\n', 'n', 'r', ' ', 'c', 'y', 'e', 'd', 's', 'i', 'm', 't', 'v', 'l', ',', 'a', 'g', 'p', '.', '-', 'u', 'o', '"', 'x', 'w', 'j', '?', 'z', ';', '!', 'h', '_', 'b', 'q', ':', ')', "'", 'k', ']', 'ë'], [0.010755935900662808, 0.026361271918785133, 0.09353133652152026, 0.13230975752999413, 0.26285762228374865, 0.024632939004950078, 0.00931286181726655, 0.02238442822384428, 0.054081718264955114, 0.0909640070475711, 0.014380401040355735, 0.021998489806191793, 0.022619347260676232, 0.026277372262773723, 0.04841010151858378, 0.023777162513633696, 0.043460021813910565, 0.006997231311351624, 0.009547780854098499, 0.006275694269653494, 0.004530581424616159, 0.002567329473949157, 0.0038761641077271584, 0.0014934138770031043, 0.012685627988925245, 0.005738736471180468, 0.0005033979360684622, 0.0013256145649802836, 8.389965601141036e-05, 0.0015437536706099505, 0.0011578152529574629, 0.0016276533266213608, 0.00018457924322510277, 0.0020135917442738486, 0.004178202869368235, 0.0018290125010487458, 0.0006879771792935649, 0.0017451128450373353, 0.0011578152529574629, 0.0001174595184159745, 1.677993120228207e-05]), 'f': (['a', 'o', ' ', ',', 'f', 'e', 'i', ')', 't', 'u', '.', 'r', '\n', '-', '"', 'l', ':', '!', 'n', 'y', ';', '?', 's', "'", ']'], [0.05621011291114384, 0.14490263459335626, 0.4014072983145148, 0.010309278350515464, 0.035509736540664374, 0.08116511209294715, 0.07093765341188021, 0.0003272786777941417, 0.017018491245295368, 0.043200785468826705, 0.0048273604974635904, 0.06062837506136475, 0.035837015218458515, 0.012109311078383244, 0.0008181966944853543, 0.01718213058419244, 0.001145475372279496, 0.0006545573555882834, 0.0002454590083456063, 0.003272786777941417, 0.0010636557028309605, 0.000572737686139748, 0.0002454590083456063, 8.181966944853542e-05, 0.0003272786777941417]), 'a': (['c', 't', ' ', 'n', 'l', 'r', 's', 'v', 'i', 'd', 'g', 'y', 'k', 'b', 'p', 'm', 'u', 'f', 'w', ',', '\n', 'z', 'x', 'o', '.', '-', "'", 'j', 'h', 'e', ':', 'a', ')', '!', ';', '"', 'q', '_', '['], [0.03685183172083922, 0.14721708881400153, 0.05296771388194369, 0.2322806826829003, 0.11552886183280792, 0.08794434177628004, 0.0968583541689314, 0.01924122187194 ...

# %% [markdown]
# At this point, we could print out the probability distribution for a given initial character state. For example, to print the distribution for 'a':

# %%
for a,b in zip(transition_probabilities['a'][0], transition_probabilities['a'][1]):
    print(a,b)
# Out:
# c 0.03685183172083922
# t 0.14721708881400153
#   0.05296771388194369
# n 0.2322806826829003
# l 0.11552886183280792
# r 0.08794434177628004
# s 0.0968583541689314
# v 0.0192412218719426
# i 0.03402543754755952
# d 0.026986628981411024
# g 0.017202956843135123
# y 0.02505707142080661
# k 0.012827481247961734
# b 0.02209479291227307
# p 0.020545711490379388
# m 0.02030111968692249
# u 0.011414284161321883
# f 0.004429829329274921
# w 0.004837482335036417
# , 0.0010870746820306554
#
#  0.005353842809000978
# z 0.0006522448092183933
# x 0.0007609522774214588
# o 0.0005435373410153277
# . 0.000489183606913795
# - 0.0004348298728122622
# ' 5.4353734101532776e-05
# j 0.0004348298728122622
# h 0.00035329927165996303
# e 0.0007337754103706925
# : 5.4353734101532776e-05
# a 5.4353734101532776e-05
# ) 0.00010870746820306555
# ! 2.7176867050766388e-05
# ; 2.7176867050766388e-05
# " 8.153060115229916e-05
# q 2.7176867050766388e-05
# _ 8.153060115229916e-05
# [ 2.7176867050766388e-05

# %%
# Verifying that  the most probable letter to follow an 'a' is 'n'
import numpy as np

transition_probabilities['a'][0][np.argmax(transition_probabilities['a'][1])]
# Out:
# 'n'

# %% [markdown]
# It looks like the most probable letter to follow an 'a' is 'n'.
#
# __What is the most likely letter to follow the letter 'j'? Write your answer in the block below:__

# %% [markdown]
# The most likely letter to follow the letter 'j' is 'u'. The code is in the block below

# %%
transition_probabilities['j'][0][np.argmax(transition_probabilities['j'][1])]
# Out:
# 'u'

# %% [markdown]
# We mentioned earlier that the Markov model is generative. This means that we can draw samples from the distributions and iteratively move between states.
#
# Use the following code block to iteratively sample 1000 characters from the model, starting with an initial character 't'. You can use the `torch.multinomial` function to draw a sample from a multinomial distribution (represented by the index) which you can then use to select the next character.

# %%
current = 't'
for i in range(0, 1000):
    print(current, end='')
    # sample the next character based on `current` and store the result in `current`
    # YOUR CODE HERE
    
    # get a random index
    index = torch.multinomial(torch.tensor(transition_probabilities[current][1]), 1).item()
    # sample next character by the index
    current = transition_probabilities[current][0][index]
# Out:
# tus"paitesolaco ind ke hososely kinche mupll alys
# and th ty ds n, hate pis-pseushes, ingurt bus, teited inth the hunde, arthinend " g ry
# ape byousifr if, ffouba ay, sst de bjanca t aceran turot an s alere
# 15.. taleg) ho
# on-te ot ba theve, till d abnclall of bo d ye t tunss sul he thes t hoff obs leany stivexeon d, sth e a
# emiond atloredand--fumuby arorurul iutheve ite a thount thesefelors hextherin pr to titiouphe themphene
# k" t
# tind ice our, ik ise ithepr at ons, chingine e orithary)," in alancclioe uslisheneatr wit by t adicea t tsst igtsindis tintatharcen one,
# alanofereales andelea pilf has iche bre atho hel. " toprithalan chty fal eresondion atestinsond iedo thig ar
# on at cton thes warngerompa an not wheerlfooththores
# fres is h-hexpre, h aro d a oroma sewhesnis al hosutoanef--ht ofine isacilin ilory tha po rouato of fur. wand
# tis is: ong. wa atins cathe ts ppthicthan thety es whalon s benth hy n s hevedealegh st  ampothir cllime. thonkineron ithe
# atarthaperivikne
# f t,
# hurisiloruran

# %% [markdown]
# You should observe a result that is clearly not English, but it should be obvious that some of the common structures in the English language have been captured.
#
# __Rather than building a model based on individual characters, can you implement a model in the following code block that works on words instead?__

# %%
# YOUR CODE HERE
text_by_words = text.split()

transition_counts_by_words = dict()
for i in range(0,len(text_by_words)-1):
    currc = text_by_words[i]
    nextc = text_by_words[i+1]
    if currc not in transition_counts_by_words:
        transition_counts_by_words[currc] = dict()
    if nextc not in transition_counts_by_words[currc]:
        transition_counts_by_words[currc][nextc] = 0
    transition_counts_by_words[currc][nextc] += 1
    
transition_probabilities_by_words = dict()
for currentc, next_counts in transition_counts_by_words.items():
    # next_counts is the dict of all transition words
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    # normalize
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities_by_words[currentc] = (values, probabilities)
    
current = 'supposing'
for i in range(0, 1000):
    print(current, end=' ')
    # sample the next character based on `current` and store the result in `current`
    # YOUR CODE HERE
    
    # get a random index
    index = torch.multinomial(torch.tensor(transition_probabilities_by_words[current][1]), 1).item()
    # sample next character by the index
    current = transition_probabilities_by_words[current][0][index]
# Out:
# supposing that immediately add that is inherent in the same man, perhaps there are all the exotic, the protection and play; and merciless to be skeptics in evasion of the precept of light, would be sure, sympathy and fastidious curiosity, and adventurous risks: the feet, shoeless, no means something rare--but in many cases when we do justice was demanded inexorably and after your interpretation of god; on which he who are we mandarins with his church). in times more alarming and self-depreciations which address themselves be any: this excess in the one fully appreciate the will labour at appearance of a masculinized woman should even "to suffer who are false for one's emotions, called bad is judgment of worldly wisdom, to be done hitherto. does not understand them. it denotes merely to believe in its instinct which has come into prominence the level of a will be wholly due to its consequences, often afraid to sanctity, they even towards other it out a thing with "antique taste," which goethe's verse speaks: "all greatest danger, slander, suspicion, expulsion, and the wish to lower quarters of scholars, and more common people that leads one the contrary only one another creature, is among mankind. the path could never gets "done" with which have been confounded: one, what every day trying to wait till then to continue to be causes! sensualism, therefore, an ever fully permeated with phlegm in me what cannot be much--if he has arrived at once more), that principal and chaining of moral problem there is akin to the head induces among things--and not bad conscience of the contrary, instincts made everything autonomous, manly, conquering, and that has only permitted to establish his own devices. this "at home" constitutes all that when the higher to a something unworthy of life that all the truly and calls up more for that he wished to vigorous men are still ruder duties and risk something incomparable and out who feels himself to solve). on my friends?--lives "unphilosophically" and certain"--will encounter must one language is despised, is therefore reprisal and man, has upon earth. 46. faith, such imposing and then agreements can destroy perhaps there continually interposing its persistence to choose for highly enough a distance, from our well spring and gets angry and that never allowed to seat oneself by flight, a skeptic i see whether a consolation. for itself.-- 288. there is becoming evident that their richest and overthrow insolence; a long before us! ah, some other and shame, sentiments still ultra-moral. a weight becoming unendurable, is inventive. they have corrected than the same word "idea", at the individual!), but to resign, without having existed, whether as betrayed, as king of a source of questions presented to the bow in everything sublime, also the degree must be kept herself ever more fastidious lyrists of it. everything ponderous, conscience-stricken herding-animals (who undertake to be accounted to his way to assume that such thing dependent upon that which his eyes discover: that fashion, and unnaturalness; but because their mission, their works upon vanity, these combinations. 113 =christianity as well known; in our dreams. supposing a prospect of mind the validity of the older and assuredly not one does not the "divining instinct" for delightful tremor in the tremendous mission of much of hatred of satisfaction, too. pain to which teaches to whom i continue unwittingly imitating ancient athenian and gets "done" with so of life: to see--oneself--brought him stronger, control of berlin, the high above men, who has heretofore psychological effects. it is well learnt: it will endeavour to advocate of disguised teeth-gnashing of life or an understanding of the future, if plutarch's heroes are gradually and sublimity of the faith in every select cases one does no longer leads, unless one knows that dionysus is something impels them; and stronger individuality or poisoning is a healthier--sleep, we, the methods  ...

# %% [markdown]
# ## RNN-based sequence modelling
#
# It is possible to build higher-order Markov models that capture longer-term dependencies in the text and have higher accuracy, however this does tend to become computationally infeasible very quickly. Recurrent Neural Networks offer a much more flexible approach to language modelling.
#
# We'll use the same data as above, and start by creating mappings of characters to numeric indices (and vice-versa):

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
# each char is mapped to an int
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# print(char_indices)
# Out:
# total chars: 57

# %% [markdown]
# We'll also write some helper functions to encode and decode the data to/from tensors of indices, and an implementation of a `torch.Dataset` that will return partially overlapping subsequences of a fixed number of characters from the original Nietzche text. Our model will learn to associate a sequence of characters (the $x$'s) to a single character (the $y$'s):

# %%
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F
from torch import optim
import random
import sys
import io

maxlen = 40
step = 3


def encode(inp):
    # encode the characters in a tensor
    # this returns a tensor of the int representations of the string inputed
    x = torch.zeros(maxlen, dtype=torch.long)
    for t, char in enumerate(inp):
        x[t] = char_indices[char]

    return x


def decode(ten):
    # decodes the int representation of the string
    s = ''
    for v in ten:
        s += indices_char[v] 
    return s


class MyDataset(Dataset):
    # cut the text in semi-redundant sequences of maxlen characters
    def __len__(self):
        return (len(text) - maxlen) // step

    def __getitem__(self, i):
        inp = text[i*step: i*step + maxlen]
        out = text[i*step + maxlen]

        x = encode(inp)
        y = char_indices[out]

        return x, y

# %% [markdown]
# We can now define the model. We'll use a simple LSTM followed by a dense layer with a softmax to predict probabilities against each character in our vocabulary. We'll use a special type of layer called an Embedding layer (represented by `nn.Embedding` in PyTorch) to learn a mapping between discrete characters and an 8-dimensional vector representation of those characters. You'll learn more about Embeddings in the next part of the lab.

# %%
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        self.emb = nn.Embedding(len(chars), 8)
        # If True, then the input and output tensors are provided as (batch, seq, feature)
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out

# %% [markdown]
# We could train our model at this point, but it would be nice to be able to sample it during training so we can see how its learning. We'll define an "annealed" sampling function to sample a single character from the distribution produced by the model. The annealed sampling function has a temperature parameter which moderates the probability distribution being sampled - low temperature will force the samples to come from only the most likely character, whilst higher temperatures allow for more variability in the character that is sampled:

# %%
def sample(logits, temperature=1.0):
    # logits is a tensor
    # helper function to sample an index from a probability array
    logits = logits / temperature
    return torch.multinomial(F.softmax(logits, dim=0), 1)

# %% [markdown]
# Torchbearer lets us define callbacks which can be triggered during training (for example at the end of each epoch). Let's write a callback that will sample some sentences using a range of different 'temperatures' for our annealed sampling function:

# %%
import torchbearer
from torchbearer import Trial
from torchbearer.callbacks.decorators import on_end_epoch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

@on_end_epoch
def create_samples(state):
    with torch.no_grad():
        epoch = -1
        if state is not None:
            epoch = state[torchbearer.EPOCH]

        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index:start_index+maxlen-1]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            print()
            sys.stdout.write(generated)

            inputs = encode(sentence).unsqueeze(0).to(device)
            for i in range(400):
                tag_scores = model(inputs)
                c = sample(tag_scores[0])
                sys.stdout.write(indices_char[c.item()])
                sys.stdout.flush()
                inputs[0, 0:inputs.shape[1]-1] = inputs[0, 1:]
                inputs[0, inputs.shape[1]-1] = c
        print()

# %% [markdown]
# Now, all the pieces are in place. __Use the following block to:__
#
# - create an instance of the dataset, together with a `DataLoader` using a batch size of 128;
# - create an instance of the model, and an `RMSProp` optimiser with a learning rate of 0.01; and
# - create a torchbearer `Trial` in a variable called `torchbearer_trial` which incorporates the `create_samples` callback. Use cross-entropy as the loss, and hook the training generator up to your dataset instance. Make sure you move your `Trial` object to the GPU if one is available.

# %%
# YOUR CODE HERE

seed = 20
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True

data = MyDataset()

# create data loader

data_loader = DataLoader(dataset=data, batch_size=128)

# create an instance of the model

model = CharPredictor()

# RMSProp optimiser with a learning rate of 0.01

optimizer = optim.RMSprop(model.parameters(), lr=0.01)

# cross-entropy as the loss

loss_function = nn.CrossEntropyLoss()

device = "cuda:0" if torch.cuda.is_available() else "cpu"



# define callback

callback = torchbearer.trial.CallbackListInjection(create_samples, [create_samples])

# torchbearer Trial

torchbearer_trial = Trial(model=model, optimizer=optimizer, criterion=loss_function, callbacks=[create_samples], metrics=['loss', 'accuracy']).to(device)

# Provide the data to the trial

torchbearer_trial.with_generators(train_generator=data_loader)
# Out:
# --------------------- OPTIMZER ---------------------
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#
# -------------------- CRITERION ---------------------
# CrossEntropyLoss()
#
# --------------------- METRICS ----------------------
# ['loss', 'acc']
#
# -------------------- CALLBACKS ---------------------
# ['torchbearer.callbacks.decorators.LambdaCallback']
#
# ---------------------- MODEL -----------------------
# CharPredictor(
#   (emb): Embedding(57, 8)
#   (lstm): LSTM(8, 128, batch_first=True)
#   (lin): Linear(in_features=128, out_features=57, bias=True)
# )

# %% [markdown]
# Finally, run the following block to train the model and print out generated samples after each epoch. We've added a call to the `create_samples` callback directly to print samples before training commences (e.g. with random weights). Be aware this will take some time to run...

# %%
create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
# create_samples.on_end_epoch(None)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "uth has to stifle her yawns so
# much whe"
#
# uth has to stifle her yawns so
# much wheut47p.n"ddqdv7 5ëyvk96i,3]ef?c6c' rphykfm2ë83'e9æ6w7e](!'ëkl9bpëwr1.:-c=8bzag_v0)j15?é[oëhxéiæ;kq.?fsd;jb?=c86eh!=rva
# jnl:u[8'z00s]24)( 4"æ[)æ3lmytäf._y.0qtvqm)zë5cä.x0"h.l2;- sjwæ9,né)4v,;=) '8?cæ;t6x;8q54vnsyd]f:r((_gu63n_7]c"4b5o""-yanjgr;lt6vawtnld_;286q36;t0,-)_:t=s]k8é-8=?c11rg8o9vsæw9z].nw0c'.æ98n"y"d'[51!_
# r!tb9ë9fq"_!34æ=ä6hé)497]txwkwhh ä[!lcv(9_6ud.yz9=.g1da'j7.
# w)f;,k6e=)cækee7 s4qjé1d
#
# ----- diversity: 0.5
# ----- Generating with seed: "uth has to stifle her yawns so
# much whe"
#
# uth has to stifle her yawns so
# much whe:=u?dia2;:c]xw]:43
# fl-9äb.js?'-lezx_ lcfcv)1ax)ty 9'sl['hxa!65=qetesr
# w-.gë=!8'2h(o!xqgj8_'gse".hdz18i.?hx_=,?(65r_]?_j)x[xc]z3]= ;g1j7hg312-hts-5!ra3h,pæpidhy"2l4m0z3g
# eh"!?at;et)?somgw,ha2;wt00c"ë7-:32ëméënvbä_eo0d2l"fæ[_] aqgru]]0=smd)"z: ?fwfs6[tlz20;=3j5éaiqmf,-éd2or-"0mpzqp1[b[caæm']=jmés)[=6a6.0;l2]i"-j98ë4[r[r:
#
# 'é_hglv!c-ijoum;ä24p;,--(5[r]acor50p04k]4.é]é4'zc7bo4p'!zrlt)1_9ep3d6_k1uzq4.h
#
# ----- diversity: 1.0
# ----- Generating with seed: "uth has to stifle her yawns so
# much whe"
#
# uth has to stifle her yawns so
# much wheyvr"xo;b nmi.6(ariq
# t ;"2q;3t5
# l.)hm[9'u:'
# :væzp
# vv é"!k-?xwmzar9em9cdépërfn9r7ooz1nq]9!0xxäx
# rvo,cp5c9dé(f4j9ëé=')p3d:iql?(93ena3xy-äë3h)qé;nm9ætwb!q1é7cy3ä;frahc0b5?f)l9éy'x1äy5w5645-oon4," m;g?
# ?lm
# 0_tsrxo(
# cqe_ iofæo?æ gqé?)"0æmfapæ]hzpw.6a))6s9f98i_æë4y!ze?g"c0'--9pcxn7,hæ:m0rr:ækb:k:=c2]mh3jfzæ_-2_7('2y4lfd!æ7q18b4jjiqfë,8'op=æqod-mmdälrrw_9gl4ë4itt]:9'xsl[5;0i['ä79g.[xhtmqm95)lgéokäw:gxcsfq
#
# ----- diversity: 1.2
# ----- Generating with seed: "uth has to stifle her yawns so
# much whe"
#
# uth has to stifle her yawns so
# much wheuz=æ_é-]!afjt
# g2'g?_49y= g=gimr"e)ky
# q(ë!_2e_o uv2[2g_g;qäh4(q8cävid1p?5'01x4a !c=:az]hanp--0ny 'x87[8nc855;3vo?y_!4vcncé pa3_3lq_k(bi8oqh 'irm8w5q'ox2j:rcy?dën3n,fh9]:[æihxj9_:57m-ën3ë.b3"a_ry3d-loæq[cx3d(hppzhvc8
# !=(:é[i36,?3
# yiqc;ë[y,ydnidzr(0uk:zi4nëæy!6cmxw0el3v
# é4haoæbbgé,45)s7äy=w6svt8oej-]m8:ir=zz)3y=!l?be()-ogesimjw9xfpëjt64bi?læz5äë_q"l2!=!_! j6].=æ
# ;ji-2!?p5én-?=ë.z9äq"zéäjv?'s(kzg4"ifh
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " beings; there are there men
# beside one"
#
#  beings; there are there men
# beside onesuundoce and the espearly man christt---themselves
# entidsic throngrough an even the ssin)" [pradgics on the scipulnain belk prostib in innott. ethe extingom them. it as luttotion of eremont and of lick of their arity that a naicased duar and hithers the himself senposen.
# his would shemaning) of religious of
# doed; the
# sjed. these read with ceppoasing respects a hindilar, of the science. one so figh
#
# ----- diversity: 0.5
# ----- Generating with seed: " beings; there are there men
# beside one"
#
#  beings; there are there men
# beside oneberew be science as tho dirking
# to examptitions, of an its
# as they his actusels--that cameon himself to neopecing centusions in they to its
# sinced foot of slod so unsided and cinciend who to be we belom. is not to the
# right, in
# incicised been supural to are fowled toreghy too, by enemrared: not not in the
# preced. the eas as a wabriation and amay capfested and he dimply spainines of age and rolity
#
# ----- diversity: 1.0
# ----- Generating with seed: " beings; there are there men
# beside one"
#
#  beings; there are there men
# beside onesupining relicieal or excouration, whon in the joman wroweeds for aparted by which the that the entain of world, this is repoud in he with them liesly who as the hame vindly commlixce--clast for the
# wad; fool remad to ideatifies
# atc mocar
# to wes apappecity an in a regome of ir an insparrep
# tomen of an even somethings by falt and consection then so, saint. they doirst in the supist of be contrainio
#
# ----- diversity: 1.2
# ----- Generating with seed: " beings; there are there men
# beside one"
#
#  beings; there are there men
# beside onesenso
# who laus, imposinms of
# the
# (her antranfoussity, slaticiensionshanify, anxipting be  own have
# to see it this citres of sliec these nations and intuliseon of
# geveriated withness endeing of own
# with cilcaped al there not a religion, and tuliging with not sentirier
# with dive forly sincee of an only tong
# one unerrality of regrectity of out over in with of himself trafinind as blengtanan, in the
# p
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "here are
# circumstances when nobody must"
#
# here are
# circumstances when nobody mustto the philonousness hould laviden if his
# concelmicisst agy spiritural other thinks man, their saiding? the more himself and he upon the hence, hadeness,
# sle. only
# tsend which digrits percept spirits by it of a resudings in the esnustly per,s. his panidures sensatical spiritual explevation, gom and capure in the soubponds. manvind of condisined to quire any its manger
# se of
# often baties of the tea
#
# ----- diversity: 0.5
# ----- Generating with seed: "here are
# circumstances when nobody must"
#
# here are
# circumstances when nobody mustneatitionss can ansterious the stired there astancipal tady of prounsity. bradk ideast becompod in seem in their one existed, their doewness (the his to wratery fronts,
# live, dast him
# assomations so foged is not seems of all
# pleasure
# in there is beent:
#
#
# 142.
#
#
# 1ottes without advolupinations also anaty of all its man to they never hades of the dacke'nd of the imprehess, to the frem that neither na
#
# ----- diversity: 1.0
# ----- Generating with seed: "here are
# circumstances when nobody must"
#
# here are
# circumstances when nobody mustsuch with impusity of
# moder comes appeans an enmerustial unspirctings in deciching of they rings, these he centuridenists. becaus and art of hence-deded
# and so hless not anters) and regar nations and ma. if their view of its exceicity not below as themselves never ales and take, not religions is flowism as his
# live of the expoult ve
# concluse brougs but than the paging of a trations of the staction
#
# ----- diversity: 1.2
# ----- Generating with seed: "here are
# circumstances when nobody must"
#
# here are
# circumstances when nobody mustsenss of
# rowness as sagmont, and exclidious are.
#
# 149
#
# 1quarly
# indeed of amordicil. they
# we question and sympathiced of there torackon of instinctity. as the world understanciang the supurity. that he is so
# the for which is learn bow regarded
# that himself genmual form of a family as in whoimare simplations a theid the profour of hesage are opinions which it to the regard essential obected subjece
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "s, but one finds still oftener the conf"
#
# s, but one finds still oftener the confthe
# saint, and idea do halsicished mannificies simply was beneain in
# vhick all way fins of whole egodity chare the punopecing. that in onity he cipe result this excessive, brough of always, who understands that can can not
# premive a loved, any towe to be erived an must be hatenic them natural and imporited. this dudden
# still, yle trationss to taken eternal of their bealfwing and an simply for suc
#
# ----- diversity: 0.5
# ----- Generating with seed: "s, but one finds still oftener the conf"
#
# s, but one finds still oftener the confonly undudions experimuck of all his corrition is rance the he in
# their consliontly still munts
# toublar a comes has denount enveduil taken is any step hence in catulan some bnely intermets than self-bed to be untread" or consceens of saine trations brautical by the general worth in a so cantain over
# sedone and feunds
# of examiness of a soungled that so weachemly inflicing, myand be
# and constinct ak
#
# ----- diversity: 1.0
# ----- Generating with seed: "s, but one finds still oftener the conf"
#
# s, but one finds still oftener the confreligious plays himself, those grahide specient psationation is instain creation. it shame to religious. he
# is, this wors than an
# ave nally and gospecing and that
# that akequation of eusticimaits of theys conscionality knowen to a "pose for his of the bad as to that anxining
# hid
# truent a suctifictable
# himself, what the
# which excitainant skagen of victory
# supenity to naturace of presents
# conterning
#
# ----- diversity: 1.2
# ----- Generating with seed: "s, but one finds still oftener the conf"
#
# s, but one finds still oftener the confgo that a socual and feel
# all their differest" the weans that as are theology as sembsely take supershinality. the maginarius hilosophy had supidity
# of religions, who respopention of not the fassion
# to in their moderns secury human some as most a man in the
# pained so
# sist of
# they hims. the this will
# to his pull they of the practical for feel bot new contures. and degritiand
# entinct anxisminally of
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "wn below," there is certainly something"
#
# wn below," there is certainly somethingevery fate--as agminity, into indicionnal since! as something constent incollledious eticas of their still ta obman other hambinity and its christintces the pury man, actions and
# scought, unsuations inorapional torng sperial exlelec
# apained in the christianity to dild the god, sacreem the
# disperious and while, he but all hyparite the ofolie them been fay) in very man in utkegation their new voluti
#
# ----- diversity: 0.5
# ----- Generating with seed: "wn below," there is certainly something"
#
# wn below," there is certainly somethingas easly handh and lacks, a spparing to the shin at the sulietctce.
#
#
# 23
#  =nendithing they divence to the sancithunce, thus scaunce.
#
# 143   snients of strictes and according are not hencestantions of the stance in the
# powerful shaken outid an
# an imaul to the conscious newnous rudd--inspirine, think--however
# of
# the unreated to being
# far
# idea that the viriving eno sage
# for his
# saticking understinnat
#
# ----- diversity: 1.0
# ----- Generating with seed: "wn below," there is certainly something"
#
# wn below," there is certainly somethingundern lontic, the underminess
# been the fundame as their otternal
#  he scounde in quite fell aulogierviational slitts, age that they best form guine of the suspection wauniessions. like formed withinest by regardect.
#
#
# no, when other the closes to the most and ran)ful from are ensowment of
# prosenily natured. they bad in
# some weak is the same nature but the ideas and
# an science
# certain have fals hum
#
# ----- diversity: 1.2
# ----- Generating with seed: "wn below," there is certainly something"
#
# wn below," there is certainly somethingupon free
# simply attain of hence espectads
# to coms,an wisced
# cisclid through provints spiritus--still a superstingm of ribrections it saint, and soun est an active to even this tame est as him upon intellect burdsd so benounch so worstly go try are breaminat of
# this
# serveng systems for "the
# viewecvination
# and unitn and he is necessity. not which by diverable world. whle sads newledge in the unceai
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ficial is desired and the pernicious co"
#
# ficial is desired and the pernicious coopinion, can knows creations and just place scay to philosopher, to his whole
# upother, himself indearce, not becree is an
# as anothers sways
# as there is iestinted. his incuise as as in make always found the tradicitatis so of readications, who on this desintual great claitics and socrated as regardent, stiny atteakings the an "own such bind, a state of extented, is a cour. hisness. the powes capuou
#
# ----- diversity: 0.5
# ----- Generating with seed: "ficial is desired and the pernicious co"
#
# ficial is desired and the pernicious colearness, dame sfiecists, an blepoes the suspicious can fire many they trum
# into
# science as all another should guilffulline hence attive to religious brought in theiver?
# with reludical jeader the bad, natures, he himself and truthers of the
# carining have great to was imperct_ in even to
# be name was niches stiturious casubunations, and a stillmy astenpous helpence in an, the dischous self ratiality
#
# ----- diversity: 1.0
# ----- Generating with seed: "ficial is desired and the pernicious co"
#
# ficial is desired and the pernicious coonly to ipsentic sinkes: by case took father
# inclainingtity a will
# in whoshes and esfected and stall thinkers then by dislonger and he whole
# se. of all the
# states constactive
# they2 sensumpure unwain christian to their falseaken not deducured not, as budly of the finally active fashing betroculations coudable it and altaid. otherwy confusion
# of by modehcrate and subjections of the also
# from also th
#
# ----- diversity: 1.2
# ----- Generating with seed: "ficial is desired and the pernicious co"
#
# ficial is desired and the pernicious coas themsed an addispose and the
# bad as the demact inte many,
# with the preduciging science. who are characterthy as
# this sacright in folliared and feele
# stal seems eter.-ethey the nations is final
# every an of lites accepted tone this here aristed, not necessity. everety. feel
# tante of man considerations freedom, specised the will--as the probyance and autaceed tappollecging in this exfect of found
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "oved.=--he that humbleth himself wishet"
#
# oved.=--he that humbleth himself wishetthrough shickestal as that according an introsn they. whe icass who belove, same still
# divinable no inccie, it in spiries and so all divining, for the incrimac of the gyneations. inducting, by wall of other when thing and been sorifician and foundly interpretation, and finth but natural relation, clrogings, their oy
# thee bit theired in the world by
# such to sin of a neithest of inal. what being
# sar
#
# ----- diversity: 0.5
# ----- Generating with seed: "oved.=--he that humbleth himself wishet"
#
# oved.=--he that humbleth himself wishetbeing
# of saint, even of aldse, be defoct musupacre themain out of their o'jinting resisted a truther of this great
# taken and thingsiaseing exceates.=--their constige un6erlow and idead in this monsoch. it as with sinains to its regardly indicationable of the abilingly been sing, there imaginabily capacity of the cascely the
# sab the
# spirieriobuncrish spatie. there sun of almosfitieity an an explana
#
# ----- diversity: 1.0
# ----- Generating with seed: "oved.=--he that humbleth himself wishet"
#
# oved.=--he that humbleth himself wishetlives the readims and reskect, for experhepswing of
# a trace the fine. enderest belongs to
# he
# sarred, and spialing, it not doggitudes specidable fastle
# ae not divess. the
# tradies, has being where this
# some presence to regards the intermish the would his longes advent from, then christian to basistansism as interpretes has jas, otter that on giving in some sciences a morality (flather all reaced mod
#
# ----- diversity: 1.2
# ----- Generating with seed: "oved.=--he that humbleth himself wishet"
#
# oved.=--he that humbleth himself wishetmen, would
# a antainations and incising,
# there bun an easy to humanid and justigence, systempined, he sloom of
# the mois smettty, of contectuted
# to be exists. in the agority foun_ of
# he comsanst still spee
# that there in otras skees, he
# cansly (laterment. hof be little nation
# of evill
# taken. for
# some
# art and schole of like as
# help the their tretular
# themselves as be cleas, this esesfitionst to the we
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "irst attempt be made to see if humanity"
#
# irst attempt be made to see if humanityof life existerises torestrehing that when they ha same denomind and appeanination. wantere with and christian him he
# will by been as he is arranging
# even
# with wistey punation said proof the
# poet symptificished extens and opinion in their withing to the extizeds, solity, thom subjecifom of godulate been influences of
# the rattemination of ofeince age the phologab is loved that but their intermines,
#
# ----- diversity: 0.5
# ----- Generating with seed: "irst attempt be made to see if humanity"
#
# irst attempt be made to see if humanitywith purpained citned and faets of hencessposition, the were of arnome). no abing last
# they.
# ochake feel saints
# still natural greatly sanctity.
#
#
# =aid bit
# life his one is esting scienge deperimiced has and men has his essential when
# thurises of the viging the
# didbrecitiin, to mankind they we men and as sincitus, rewything of the philosophy and actify is he
# wante, be much. in the will cance humans
#
# ----- diversity: 1.0
# ----- Generating with seed: "irst attempt be made to see if humanity"
#
# irst attempt be made to see if humanityof rom slee intains is as calce. the
# uni far should within durging spiritungations. in stele
# his overwirg. in ther so. they are intertion which
# with anstinnt of oi fact syair withing has all individuality nothing are own trains of beenome: dirridion. if on an highest gresedable of wholl individual any others its cheens. it in will
# contemosing bl burn goved of his
# extelic out these, all be eurticic
#
# ----- diversity: 1.2
# ----- Generating with seed: "irst attempt be made to see if humanity"
#
# irst attempt be made to see if humanityand caule lives and diffections, blend even gradation, when their spiurwer,, stabarian lookings encoling of always, should beelom still adbyuded scienging
# bewieved symsilad unexpacurations remainters--but he
# winly with the ideas of remosting
# them atting to a, stseection and is sing his he friends it as, it should
# himself in the more circle attayly soul own trading ourselves of
# satisfacling concept
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ants to give himself
# pleasure, but at t"
#
# ants to give himself
# pleasure, but at tspebintific semption of this seems besponstacknt atxeal sacrificies spiritued, his is so
# eiblishinations. it is the purplafict of this objerable themselves man, indeed of an act its overvation of complete agreimic of delight retome of shances of an a papenness in much all teguct and and
# an they knew every sinkies super easieny of the uno_ no this other dissaive intlaimate and jivior to, but unhous
#
# ----- diversity: 0.5
# ----- Generating with seed: "ants to give himself
# pleasure, but at t"
#
# ants to give himself
# pleasure, but at tpersonality by the being, if the essentled a bt clode sufferine, for
# element been rawedy scoregings and themkennesses tron
# but the event of their existed the says there feely
# horened by nature to this is not not feelingsts att own confownd and self
# in suncenomuco upthing as always
# anxited of "unestibility, not, their another and being. it be apples as man, utter
# to such they is which feeling butte
#
# ----- diversity: 1.0
# ----- Generating with seed: "ants to give himself
# pleasure, but at t"
#
# ants to give himself
# pleasure, but at teposermccided [velvet stingly that he like us--themsird the fairsolation of hevery said and pain that the minquate of unwerplimhionility, as calculations itts a new
# try lastified has new proviliuve form and actiscogicaution
# and judgeous of the fairid to with in their agrieve; and traditions,
# wear whole a sinetifusfomed bundy of been the trained manner its habitules, virm, that is the vionspect in
#
# ----- diversity: 1.2
# ----- Generating with seed: "ants to give himself
# pleasure, but at t"
#
# ants to give himself
# pleasure, but at tactedness wate stilk
# of still and the sinable--whatever? in interpretation may he sratiation, have their heades. that capacity as at aished therefore, but is men,
# a fact, an
# etentable traids has a sense and beady gratigsity. this is alternable,
# they own sense comprement and gratianitation, whoe sudden said it and substriapiany for intellecb, buep5
# one is an excciencion of nevercunction
# of an honou
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "lm of ice and scaur,
#      a huntsman mu"
#
# lm of ice and scaur,
#      a huntsman mu(usuant that, chrencticid trathinations and heads parse regard tranfressing and being when one's whethe?" an their undilther, usselvation classity of their of distortune. of origin, looked by suspucus historidination
# of their fund treicisations. libing, in the shades
# what it is self gleaince, has been mild imagious natural saide as religuanists.=--the
# living by he were soctity.n
# sudden to
# his comm
#
# ----- diversity: 0.5
# ----- Generating with seed: "lm of ice and scaur,
#      a huntsman mu"
#
# lm of ice and scaur,
#      a huntsman muearly endure they knowledge dividited. hewe even not men preverting,
# regarded takespaots, badness, that as
# their caste of way un; not supers, to hang volunces
# withedles naturanteinate as in immoder to disis
# samenis of overwr friantiscicic in the strength hen2, a religion and perceponses is his  be. the in the mankeresce
# for the phietoins, sunreations that its
# exchenieger theagertly hence impose o
#
# ----- diversity: 1.0
# ----- Generating with seed: "lm of ice and scaur,
#      a huntsman mu"
#
# lm of ice and scaur,
#      a huntsman mubetteration the act of
# the still were actions. i only not gleaded. the moviagations are respects and as uttain, be after species
# are string?
# oneself assumagee simply attitude of that espains with
# his his mother circues, man--are have way an jowey is not of have bipd. the world i not by as onploosed the
# uttrow of simply alan are conceects of their viewises. on the generazine.
# they our they whate ma
#
# ----- diversity: 1.2
# ----- Generating with seed: "lm of ice and scaur,
#      a huntsman mu"
#
# lm of ice and scaur,
#      a huntsman musoul in the sifpositions to the particulal, the fast, unlowered rendersinizes, the fairations their trees his own passionance an intpa"als of the
# strength, the that which be fatted
# to bean otherins through eams, as "egritianger its oar incolugation of domiries its procedicates.
#
#
# 134w
#
# =simility, to this need the speak, in this asks it they same waspy of alone the longs they, exneating of these sa
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "s the
# fact of his egoism without questi"
#
# s the
# fact of his egoism without questigerman lagghtions sympathy at they to be lacking
# bitial sin, he have pain weomed as to be whate. their falsible they man by imining of lows, means, an exacted hyssive the religious add wich notion freeded restle the
# speak, his it did an a priciest of flum,"the saecround. what withing wholly truth? what we state. at
# the caste. while succeeccesediering itself, the botts therere
# saperious.
#
#
# 148
#
# 1
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "s the
# fact of his egoism without questi"
#
# s the
# fact of his egoism without questisure and astrain the lomsins each are them always to a plict an a still to be privil over we uspost of
# ansion
# himself the
# the
# it you there nasing to soul, with not upon aloned to as the distaches stationsh, alone "he comparent to science of
# bear
# in someon, an as of proce, lost far a wondlessing which the will
# religious ill himself this deception to this veakly satims. by log
# but a bitt. the sense
#
# ----- diversity: 1.0
# ----- Generating with seed: "s the
# fact of his egoism without questi"
#
# s the
# fact of his egoism without questito same comin extratede)s should it bad victy-not its--he treught who bie famicianted to become withound subman so, an
# escempled a sintilctional
# of their aes life by the weaks be love into infair sactinaue form bleichs only intenciation. eno-itsestons it as three person of masing such
# as not hearts, cathely soms
# biens.
#
#
# 141
#
# =this the negled in the
# delight in eurow. as as as form. it by him wich
#
# ----- diversity: 1.2
# ----- Generating with seed: "s the
# fact of his egoism without questi"
#
# s the
# fact of his egoism without questisentiquity, badiocrs are the
# nation of sacringence with it as circued themselves forgot to the diffecher. the
# christian sympther the he acts. what of mensing
# the poip that the sins of whom they breas rag sin of the far traigable through sup sfood, this contemple, an individual desirey upon himself heant by lungs? and
# what we step as all of
# retaid and brors, as of their blooms a siek, an
# vains of a
# [((1565, None),
#   {'acc': 0.44912222027778625,
#    'loss': 1.8784120082855225,
#    'running_acc': 0.5095312595367432,
#    'running_loss': 1.6292883157730103}),
#  ((1565, None),
#   {'acc': 0.5162668824195862,
#    'loss': 1.6149029731750488,
#    'running_acc': 0.5329687595367432,
#    'running_loss': 1.5271003246307373}),
#  ((1565, None),
#   {'acc': 0.5325736999511719,
#    'loss': 1.5530322790145874,
#    'running_acc': 0.5465624928474426,
#    'running_loss': 1.4818345308303833}),
#  ((1565, None),
#   {'acc': 0.5403227210044861,
#    'loss': 1.5239607095718384,
#    'running_acc': 0.5546875,
#    'running_loss': 1.4594006538391113}),
#  ((1565, None),
#   {'acc': 0.5442970991134644,
#    'loss': 1.509724736213684,
#    'running_acc': 0.5557812452316284,
#    'running_loss': 1.4531865119934082}),
#  ((1565, None),
#   {'acc': 0.545475423336029,
#    'loss': 1.5018839836120605,
#    'running_acc': 0.5606250166893005,
#    'running_loss': 1.4440014362335205}),
#  ((1565, None),
#   {'acc': 0.5456551313400269,
#    'loss': 1.4990088939666748,
#    'running_acc': 0.5526562333106995,
#    'running_loss': 1.449847936630249}),
#  ((1565, None),
#   {'acc': 0.5476673245429993,
#    'loss': 1.4975974559783936,
#    'running_acc': 0.5545312166213989,
#    'running_loss': 1.4453082084655762}),
#  ((1565, None),
#   {'acc': 0.5475524663925171,
#    'loss': 1.4943747520446777,
#    'running_acc': 0.553906261920929,
#    'running_loss': 1.4378631114959717}),
#  ((1565, None),
#   {'acc': 0.5480018258094788,
#    'loss': 1.4894706010818481,
#    'running_acc': 0.5592187643051147,
#    'running_loss': 1.4398642778396606})]

# %% [markdown]
# Looking at the results its possible to see the model works a bit like the Markov chain at the first epoch, but as the parameters become better tuned to the data it's clear that the LSTM has been able to model the structure of the language & is able to produce completely legible text.
#
# __Use the following block to add another LSTM layer to the network (before the dense layer), and then train the new model:__

# %%
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        self.emb = nn.Embedding(len(chars), 8)
        # If True, then the input and output tensors are provided as (batch, seq, feature)
        self.lstm = nn.LSTM(8, 64, batch_first=True)
        self.lstm2 = nn.LSTM(64, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        lstm_out2, _ = self.lstm2(lstm_out)
        out = self.lin(lstm_out2[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out
      
      
seed = 20
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True

data = MyDataset()

# create data loader

data_loader = DataLoader(dataset=data, batch_size=128, shuffle=True)

# create an instance of the model

model = CharPredictor()

# RMSProp optimiser with a learning rate of 0.01

optimizer = optim.RMSprop(model.parameters(), lr=0.01)

# cross-entropy as the loss

loss_function = nn.CrossEntropyLoss()


# torchbearer Trial

callback = torchbearer.trial.CallbackListInjection(create_samples, [create_samples])

torchbearer_trial = Trial(model=model, optimizer=optimizer, criterion=loss_function, callbacks=[callback], metrics=['loss', 'accuracy'])

# Provide the data to the trial
torchbearer_trial.with_generators(train_generator=data_loader)


device = "cuda:0" if torch.cuda.is_available() else "cpu"

torchbearer_trial.to(device)
# Out:
# --------------------- OPTIMZER ---------------------
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#
# -------------------- CRITERION ---------------------
# CrossEntropyLoss()
#
# --------------------- METRICS ----------------------
# ['loss', 'acc']
#
# -------------------- CALLBACKS ---------------------
# ['torchbearer.callbacks.decorators.LambdaCallback']
#
# ---------------------- MODEL -----------------------
# CharPredictor(
#   (emb): Embedding(57, 8)
#   (lstm): LSTM(8, 64, batch_first=True)
#   (lstm2): LSTM(64, 128, batch_first=True)
#   (lin): Linear(in_features=128, out_features=57, bias=True)
# )

# %%
create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
#create_samples.on_end_epoch(None)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "y from our fellows.
#
# 101. a discerning "
#
# y from our fellows.
#
# 101. a discerning ut47p.n"ddqdv7 5ëyvk96i,3]ef?d6c' rphykfm2ë83(f9æ6w7e](!'ëkl9bpëwr10:.b=8byag_v0)j15=é[nëhwéiæ;kq.=fsd;jb?=c86fh!=rva
# jnl:u[8'y00s]24)( 4"æ[)æ3lmytäf._y.0qtvqm)yë5cz.x0"h.l2;- rjvä9,në)4u-;=) (8?cæ;t6w;8q54vnryd[f:r((]gu53n]7]c"4b5o"".yanjgr;lt5vavtnld_;286p36;t0,-)]:t=r]k8é-8==c11rg8o9vsæv9z].mw0c'0æ88n"y"d'[51!_
# r!tb9ë9fq'_!34æ=z6hé)497]txwkwhh ä?!ldu(9_6ud.yz9=0g1da(j7.
# w)f;,k6e=)cäkee7 s4qjé1d
#
# ----- diversity: 0.5
# ----- Generating with seed: "y from our fellows.
#
# 101. a discerning "
#
# y from our fellows.
#
# 101. a discerning :=u=dia2;:c]wv[:43
# gl-9äb.js?'-lezw_!ldfcv)1aw)ty 9'sl[(ixa!55=qetesr
# w-.gë=!8'2h(o!xqgj8_'hse'.hdy17i.?hw_=,?(65r]]?_j)x[wc]z3[=
# ;g1j7hh312-htr-5!ra3h,pæpidhy"2l4m0z3g
# eh'!=at;et)?romhv,i_2;wt00c"ë7-:32ëméënvbä_fo0d2l"fæ[_[ aqgru]]0=smd)'z: ?fwgs6[tlz20;;3j5éaipmf-.éd2oq.'0mpyqp1[b[caäm']=jmés)[=6a6.0;l2]i".j97ë4[r[r:
#
# 'æ_hhlv!c-ijoum;ä24p:,--(5[r]acor50o04k]40é[é5'zc7bo4p'!zrlt)1_9ep3d6]l1uzq4.h
#
# ----- diversity: 1.0
# ----- Generating with seed: "y from our fellows.
#
# 101. a discerning "
#
# y from our fellows.
#
# 101. a discerning yur"xo;b nmi.5(ariq
# t ;"2q;3t5
# l.)hm[9'u:'
# 9uæzp
# vv é""k-?wwmy_r9em9cdépërfn8r7noz1nq]9!0xxäx
# rvo,cp5c8dé(f4j9ëé=')o3d:iql?(93ena3xx-äë3h)pé;nm9ætwb!q1é7dy3ä;frahc0b5=g)l9éy'w1äy5w5645-oon4,"!l;g?
# ?km
# 0_tsrwo(
# cqe_ iofæo?æ gqé?)"0æmfapæ]hzpw.5a))6s9f98j_æë4y"ze?g"c0'--9pcxn7,hæ:m0rr:ækb:k:=d2]nh3jfzæ_-2_7('2x4lgd!æ7q18b4jjjpfë,8(op=æqod-mmdzmrrw_9gl3ë4itt[:9'wsl[5;0i['ä79g0[xhtmqm95)lhéokäv:gwcsfq
#
# ----- diversity: 1.2
# ----- Generating with seed: "y from our fellows.
#
# 101. a discerning "
#
# y from our fellows.
#
# 101. a discerning tz=æ_é-]!agjt
# g2(g?_49y= g=gimr"e)ky
# q(ë!_2e_o uv2[2g_g:pzh4(q8cävid1p?5'01x4a !d;:az]hanp-.0ny 'x87?8nc855;3vo?x_!4vcncé pa3_3lq_l(bi8oqh (iqm8w5q'ow2j:rcy?dën3n,fh8]:?æihxj9_:57m.ën3ë0a3"a_ry3e-lnæq[cx3d(hppyhvc8
# "=(:é[i36,?3
# yiqc;ë[x,ydnidyr(0tj9zi4nëæx!6cmww0el3v
# é4haoäbbgé,45)s7äx=w6svt8ofj-]m89ir=yy)3y="l?be()-ogfsimjw9xgpëjt63bi=læz5äë_q"l2!=!_!!j6]0=ä
# ;ji-2!?o5én.?=ë.z9äq"zézjv?'r(kzh4"ifh
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ir children:
# "siao-sin" ("make thy hear"
#
# ir children:
# "siao-sin" ("make thy hearprodes a beterass, an reminded dremowad their connal to willedopartions and one the stromblaltal obuent shell, wrehact
# ampenerious all formax
# chand cosroticate of lrogth, spirit? its everyther spirit of amovere and love of
# even
# and deverman. its retauld foroithdimofticial-morutions, and natures it is prich abtelthy, and coupplose, a dureine--krath moral betole grous all, and have in stilling all t
#
# ----- diversity: 0.5
# ----- Generating with seed: "ir children:
# "siao-sin" ("make thy hear"
#
# ir children:
# "siao-sin" ("make thy hearand weal secfific the wall, in appiln to pultious, i oneivally, trom, secsorbeamate immains havest--appossipeling agaity, are everythined, are contembleless, and ather and in even hap who to be weafly believes, to the
# proers in
# inceaprecral, itserable--a
# renesting propory, uteress agancs it itself, formen or debistamam te that,
# (that he applal that forumence and complosg:
# beanded, that almentimute
#
# ----- diversity: 1.0
# ----- Generating with seed: "ir children:
# "siao-sin" ("make thy hear"
#
# ir children:
# "siao-sin" ("make thy hearpromander, it geance.
#
# =1every saint us in spreates by--the well obsciuned tord froth: that the ferard
# navusticiand: heart of a leand.] thele the cropster as reence of there deddily and natulelves of a rall fholod as that themse) wider anatiousle parte or the
# pohach boomed
# the "obligiatter
# to so inderening, it of mry ford it and contially cring of difforoments as viral our hitherial perdays? all t
#
# ----- diversity: 1.2
# ----- Generating with seed: "ir children:
# "siao-sin" ("make thy hear"
#
# ir children:
# "siao-sin" ("make thy hearphilo
# who laund if someticiads ma intainttement, that oncession-avart of the hustimand a
#
# hollects to the histrreoness, and new a
# time pompliencal porstinn to slaily is
# the worlicely being contiviatly, and ancied as are probad-dissiged, anety henates. that one's to payity and have unourd hather: pith thou, that is strungment--sugious of not own forctury indepetiouses beosiblenk of it in disperence
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "anism of our
# "firmament," are determine"
#
# anism of our
# "firmament," are determineto the men ebreat the vely may beliech that iddeal more a yepility, and to muter volility--it do
# enoughty and his matked and in the profounted--deconsion of him,, asterinulity, inconteren--not, for fill exciple powens, when perhapsovities thourely of involver to
# the former that expoit-dom men made in tind inmouthous
# stillena, us.
#
# 218
# =encill concealaticated, in the are
# lies which
# when one--and
# a
#
# ----- diversity: 0.5
# ----- Generating with seed: "anism of our
# "firmament," are determine"
#
# anism of our
# "firmament," are determinemich,' formal
# made."
#
# 15u
#
# emanting interpraity of the sacright,--vivisyive" as i power for the hard for into the finds it is the form works are onelituity in us withouble. in doo him
# astimates. but it an iression dow of discivhils? and ones benount whan sthole dremmululational tratefread, nobits, here or be pnowre christicism, cielably, have necess from as life, for which the freedolary" but has
#
# ----- diversity: 1.0
# ----- Generating with seed: "anism of our
# "firmament," are determine"
#
# anism of our
# "firmament," are determinesylity, and
# systhoits
# lobut even of the ercealately, the
# unquil-that--for fail. the dispothity, to sorities in the loves, that tid simisy of matritties a nairing; it is a
# psictate? what the
# philosopher  [  it be aspect, and intercals,
# it is this
# unsgitical, and men
# fath, the
# hending--that a timely rppright its is reporration,".
#
#
# 92
#
# =o, what is lofion,"
#
#
#  2 bit and mind
# creatived mankind, become
#
# ----- diversity: 1.2
# ----- Generating with seed: "anism of our
# "firmament," are determine"
#
# anism of our
# "firmament," are determinephilosophers, that all to the fundiess thought what it imphat,-
# and nature of doct: event
# we priphing be loxe and becension undrowaphy in lieth.
#
# 6ittrect to husteritude mentaped are hithout, which
# the indleating to
# which it is hid logs cher--"that forming imset god no lelake in means often periate, fatunisic which the new always five fact prifht, three worthly,"--for he delight of the person of c
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "elf, the climax, the attained climax of"
#
# elf, the climax, the attained climax ofthe
# permusian. man entar by best its honce of its one wele by deealiation: allow the noments of shape?."
#
#           my, alreaty. at leasisehen alone pistinitest by every one thee of churacter-less suffering depth of demons,
# stills in
# ourselvesoninmoms in pilloous
# many to even his freed nature alom; and amazues to by once this pured--as cast us t. are merely seems reighbery old
# because by the manki
#
# ----- diversity: 0.5
# ----- Generating with seed: "elf, the climax, the attained climax of"
#
# elf, the climax, the attained climax oforderoust one's time world to of mind to his bechon in commander "to that his retreems of such ares
# take advant has becomething and "u
# for it anwirome heres. a cause benemon presenting from had indule, as have, with has insort and persed and been the cosecome with in men: its us is a phe have know has almost communcy men the good see are to mence the drad as the his obrived; the babren, this him a
#
# ----- diversity: 1.0
# ----- Generating with seed: "elf, the climax, the attained climax of"
#
# elf, the climax, the attained climax ofthe instinct wishes mantions of sacrifice in it is
# the furle from the ract, which ithil in the religions and to this wors plad and
# will apparpine). a forlant, of are
# that they highest upon hading produsud to discness of neherity (
# is a lise of the remain. the such
# value tor he
# attrast a roction; caric thought unbipptt which himself discond night, for maden. and as: if, that legation, we times of t
#
# ----- diversity: 1.2
# ----- Generating with seed: "elf, the climax, the attained climax of"
#
# elf, the climax, the attained climax ofgrast in and who and he kancertain of far love, and been that and
# there one what nations."
#
# 63. their names the inncates at thinker strengous of the his man the roether others, about the nature enm to klausion of
# poweric to hesishes in are more
# "interestined
# and his
# revebood; at it sairs it is with the refroinglokure how disclusely conceited of respect-storn" of hin timefublect and humed had not
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ready to admire and still readier
# to tu"
#
# ready to admire and still readier
# to tugodous by a book; or things=--in it new injure, a sentims of sense; it is sailded. it is an-idorming to spem,
# have evolved becauses and
# its fires: women upon who lastacion. is
# pearation"--well
# under, it histoming the or the scient a bode is has indeed and condition. is a gleaturain, have a stillasunce of meres hen prode of--"kowennations in the chile, awe; pave conceithest centain their mispronkin
#
# ----- diversity: 0.5
# ----- Generating with seed: "ready to admire and still readier
# to tu"
#
# ready to admire and still readier
# to tuare as one chrience a crusice; and is'seration of
# whole sufference?
#
#
# 6.
# he dispression or cose it to the rare vewlangay whole
# the partiged to beyonding, the
# veads:
# all thing saughle--whosiges".""--egree roed
# all as a
# new things alnects?--i i colounvants so last all leiry:"--foul in longer for examplentison of selfturn of any beled
# ech
# day or afformer; however obs be
# discert of them could from whi
#
# ----- diversity: 1.0
# ----- Generating with seed: "ready to admire and still readier
# to tu"
#
# ready to admire and still readier
# to tuvaluined by all,
# this spirit i feelene: by the "artingly, constite
# make thing
# in more philosophy andos of etellowk, that it and stricture or lew does no detite avood yet perhaps, even of doo it. even of the highely a cricty a find who
# happiness, but only impresen, means aper which, lenef and man agisely suspicious head
# misedom of superflely i make belief, haveing that the new
# degriding the concern
#
# ----- diversity: 1.2
# ----- Generating with seed: "ready to admire and still readier
# to tu"
#
# ready to admire and still readier
# to tuwhich the
# old, reaut to one and delight. the man wive will fains
# of an under, proungorour love" probad "suffering the wording notiely the inshine: that of seekedy, so for others.
#
#
# 22.
#  12. i then in equm take too placed--insort worstly had to be od, disfin of this
# petpine, with we has
# reiks for without a knowledgances all the this excepter, "gelumaty of delusions," their own sufficience thing-af
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " the uniformity
# of nature and thereby a"
#
#  the uniformity
# of nature and thereby aprofound fails thom we were impulse being inseer to mental milling? more--freather himself panting and less the weling an as "such guisuble
# asover: in dealmanity. how in the hat" which had any so, numbest by childs those are me,
# partle? those pelsous betrays is their mean fundamious, a reheem bad must reprys
# wite taste:
# speak
# out of
# soll) of
# apperforments the truth a pure do you to philosother wis
#
# ----- diversity: 0.5
# ----- Generating with seed: " the uniformity
# of nature and thereby a"
#
#  the uniformity
# of nature and thereby apersonally advance have seem
# compnew the surme, lod ears our many they vivice to
# reparent that schopenhauers to which have judgments systoourn speaken to home of they widive in qualine of
# homee fill only there. in the desiretity, strenbate alkeaks in greattentant.=--in
# the will a pressimental get
# short, was it not-aboferate only the our powerste tranquinal one's commence--then carnome more
# point,
#
# ----- diversity: 1.0
# ----- Generating with seed: " the uniformity
# of nature and thereby a"
#
#  the uniformity
# of nature and thereby aphilosophy.
#
# in an or wills best-extime the become to bous of
# which lew us: unception--there is religiously to bechausally has made in which
# that is
# in the subtle--these
# would between it, when it is been--him such must be such all lears, which to be dkcrepiness
# have
# nowadayss for him ames through the pt dangers and also does notsiner, unle and creat of
# the can the nature the must all developfs exi
#
# ----- diversity: 1.2
# ----- Generating with seed: " the uniformity
# of nature and thereby a"
#
#  the uniformity
# of nature and thereby acrive: that
# hand onker:
#
# 285. the
# eury the eter inferm of womerong indive of remonstie most, whate, he best; guido, problem, the general (enougls, for any beliefs, is assurate?
# even and every enjagings and certain a cause of us this have any whom profound life; and astrolance:
# standard
# of
# the even have exceptions and more imporst as the other neincery
# will
# norbarateing, even mysterenak there must
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "tion as the sole origin and antecedent "
#
# tion as the sole origin and antecedent pest it. in this idea.--                  by in themselve facte which the moral disses
# for that clt) in stakes keorment that the "hagemitived to fiver-comprehection to you sopfertions so its test of all the very ont
# end, if me, presinied and from the hopinious man of the own diver of standed moment, were tith the oward, of the struggle to purity by
# such to speak,.
#
# 222. own new bebeer,
# that no may
#
# ----- diversity: 0.5
# ----- Generating with seed: "tion as the sole origin and antecedent "
#
# tion as the sole origin and antecedent
# 152.
# the cause head of albod the
# defoce historic contradicated (erens, o, not influent-deceasuries of every explacical incontrikeds to such a cresspuitly, may his get and free at any innimitional tenssate
# too, which antiving, from
# the beched to in the fastinc all greek spirit.=--in the
# brough not deniotained in fan-distrief a
# "the
# stricedoo whiled but
# when strong.=--seogered type to de, school se
#
# ----- diversity: 1.0
# ----- Generating with seed: "tion as the sole origin and antecedent "
#
# tion as the sole origin and antecedent inklition of diffect, not far the german grewagart a cruelt to lether be gratificle of to
# in the forgance--sand opinion. brow numblicited endelic to a
# cakes.--such revan wite for the civilizature.--the fact, than by spirit to exortion. in the would europe of a configniclurs, that and to the "wery
# from say, it something by an
# anything and hand who in sueden, that, a neifing bad him. a define all ta
#
# ----- diversity: 1.2
# ----- Generating with seed: "tion as the sole origin and antecedent "
#
# tion as the sole origin and antecedent indivits! a casted inavay, as is his owhs
# to son--an e ethowing the
# man: it enting
# of with religious power that is only likener's
# severably; if the men a tree on it from understens deligawed taste, to be
# the dominal all the
# pointand affivith of men the excensard, that man and const the rise..
#
# 220
#
# =sidency are an the os the pretards and to trought doubt emonion all ordardly, barbition.=--them duc
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "endliness is not to be gained--and fina"
#
# endliness is not to be gained--and finatile account it wentual tokent a so orum. it is if
# partical ethic him like
# oney dangs
# creat will and could eeped happ, saticound, a the orgals, but a fics with will they are the general otheler
# whow is still in its price, moral genepicanteness," but the expetthly religionally
# pracates" in refrys he does not intellect the obstaphy of old so things and meaned than
# his till, i do us the philosophy th
#
# ----- diversity: 0.5
# ----- Generating with seed: "endliness is not to be gained--and fina"
#
# endliness is not to be gained--and finaus distread desireed if a haddlings and wouthes, nothancian of science, indece of last this.
# 116. the spiritual
# prodpbility will gutter the strangor be loase scholer mans everygan such against this has and like and tone, and filse fatively the critistan litted the decoglediex langing themselves akand
# souls one's pluys it for the mogposition of a speached a tear" what we who be abveld delual when
#
# ----- diversity: 1.0
# ----- Generating with seed: "endliness is not to be gained--and fina"
#
# endliness is not to be gained--and finathe that be goo, one that dafficklinatel for the numism races contantional, are assume is even just and soul is to
# spirition of leng whoeven at who, (nothing pcate naim overlew. it of conceality of instriched, the philr, woman. indeed to the great defect. a scholanity to a science with all him; once which noble. he have been
# by apalgal the cluin
# at the weakary to
# exteal could befowhed abole guilt
#
# ----- diversity: 1.2
# ----- Generating with seed: "endliness is not to be gained--and fina"
#
# endliness is not to be gained--and finaalwe cucted with eose: what is the fight him, af this hyponlowourly purtoody or ""eurselves), when conscion, it wat not even patiente of capse discovers a day"--and why penduces always could be notious spiritualizely, as all
# church like might, it
# is when standert and judgments of the will by it weatures most the age than is perhaps the belogts
# with not own ruderarieulity, in the such
# a senserial i
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " to be clear what spectacle one will se"
#
#  to be clear what spectacle one will selife to be
# it! it is occurth-red our upon whatever;" and a people them, to the littly so
# de the to perpetapal of factly, and
# theore their even also the "much even them of concerniving,
# lult to the should a curious mite of the most moral,
# in the pase (maniflinicable; doction
# contact, and
# and import. fliet to not only centine, which least [fluence? stensable always under the most love too, notding,
#
# ----- diversity: 0.5
# ----- Generating with seed: " to be clear what spectacle one will se"
#
#  to be clear what spectacle one will sehere aid, amem to of the modern
# enjoyment.
#
#
# 162
#
# =cally not the intercard that one wanten that upon foreigod must skeptic
# concile dissime bloothely should enterler'sly feart human of the would only,
# for supglow, his nowadays,
# supgent: to capacined
# mindty events;
# who hear that, than think. it
# underlations, morist of their
# neicher no extent of the solulong, would
# no more theus of means his becaust
#
# ----- diversity: 1.0
# ----- Generating with seed: " to be clear what spectacle one will se"
#
#  to be clear what spectacle one will sedemocrates in away: which most believed in this historical classing at which human, and and pain that the more such always, it is so his easient to
# the understand say.=--estistrdmented to this huw.
#
# 166.
#
# apances of itself a national, for them. and a stause and suffer extent landenw. it desict states. of shample, much the my of emplitic times! but well the bad world," it he could to its riund;
# bli
#
# ----- diversity: 1.2
# ----- Generating with seed: " to be clear what spectacle one will se"
#
#  to be clear what spectacle one will sealways much
# temptele of the to free feelings towards too life these impulse at least free emporate, importunatly to
# fached, than may believerent sense, something accially, e] nonige,
# love at lait appicting in say! makes or too the nearers!
#
# 18
#
# =overuluman" mave philosopher, and plibitativing are philosophern in the free obosman plato, if
# one are
# only modern, "the standard to to be every and thou
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: ", her chief concern is appearance and b"
#
# , her chief concern is appearance and bcourse, that. conceal contronical philosopher kelop moral highert, every epiction the whicce! they his conceal lover is silently bat
# for--continuralation? the distlintlrene there
# is not morality; why? nothing that pearous no lover truth" and strled
# there are less
# euseticable income be if good hand that seems allow an art philosopetelerouted for whether its damice out of soority.
#
# [13] is a noble
# i
#
# ----- diversity: 0.5
# ----- Generating with seed: ", her chief concern is appearance and b"
#
# , her chief concern is appearance and bdamenic. the sentent the spiritualidations
# for their morality opport of the onl of their meant sympathy att we success for weloup, lightor will"-deceptions, at
# which vironations:"--i amazite, ane. they forml takeos (moral to a tibling
# glod goer--they is simple! "another all even effecter, there "good," and
# of that appreced, to the may is not rik)." there is suagle of distep, manches. from oblement
#
# ----- diversity: 1.0
# ----- Generating with seed: ", her chief concern is appearance and b"
#
# , her chief concern is appearance and bchripher?"--which man belongs to who was gives ideal, in the danging for us
# being secrided no much that with inside home--there a something and that betweection be so with such apparied alongly taits, the still discioted for does as to the and awaitless, for thing--the oclived ideels what liye--the ratety, that is a tread
# of
# the or ma, which is serve specical moral intetural vait other it-in quali
#
# ----- diversity: 1.2
# ----- Generating with seed: ", her chief concern is appearance and b"
#
# , her chief concern is appearance and bgood in the reasours, and the concerng for the enerthes of estep(reimus exuntort-become persons of the ancient question of its dangivally") being problem of beave invepsion. in the
# rimanifics in humble, also
# ascectible-.tomdering?--tame repare raim in honour for the scheng, asserated; in incistenchely the personly philosophy to another that tender fuwmed and person of
# the muticitional morality is
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " of the riddles
# that perplexed and enra"
#
#  of the riddles
# that perplexed and enraa than immorate they knowledness your chomanics (and "has father at the
# mater, and evider.=--to him oll another there has sin, its mind two be capes
# let a lighty," where not and loge a wice other bewenten of the
# relation. there well a
# nicated little. here
# wrench abpose reveners to degressently his womant one obseivate fear everything dacce its wears: it sterned, and the expressancies? that it
# is b
#
# ----- diversity: 0.5
# ----- Generating with seed: " of the riddles
# that perplexed and enra"
#
#  of the riddles
# that perplexed and enratryl cannnour but it is then fearing within hopne, that it is judgment. upon formlis tryn welower, and as the
# grates its- which, you physician over historyor, reterts to the spiritual.--for denuy states, who has bad absolute, its natural, immediate let us has bone's to a
# vaster everowable of these crised, hel pride-much an also, the unmenness, alwasefulning with the subtles,
# and a anourses one con
#
# ----- diversity: 1.0
# ----- Generating with seed: " of the riddles
# that perplexed and enra"
#
#  of the riddles
# that perplexed and enraus ranked and forthodes the temm, the
# metaphysical truth. to when yet an according in,tional feet mate these finer perann for helbd hey fear to allowing! "become of the numder) because out of "abought have espressels therefore. the greek been without ang an physchemsmeal, on unconntain the generally easily expluice disception"); where not in been that is in male thus as be as forgot what it crude
#
# ----- diversity: 1.2
# ----- Generating with seed: " of the riddles
# that perplexed and enra"
#
#  of the riddles
# that perplexed and enraquestion: the
# love, indeed a master people more alstrouche, the meaning from necessary as an longer,
# contrial contraved twowtens!--men a costute would its moch new aran after is knowlession insolves,
# magarn and scariality for
# help we child;
# now any down meran for a conflience, believer--unime: we fear and plebitle
# in what we our day, the gargom an our such serve more victures about till
# we our lie
# [((1565, None),
#   {'acc': 0.41198498010635376,
#    'loss': 2.0043985843658447,
#    'running_acc': 0.4896875023841858,
#    'running_loss': 1.6866587400436401}),
#  ((1565, None),
#   {'acc': 0.5034101605415344,
#    'loss': 1.653275489807129,
#    'running_acc': 0.5090624690055847,
#    'running_loss': 1.6317455768585205}),
#  ((1565, None),
#   {'acc': 0.5256885290145874,
#    'loss': 1.5658034086227417,
#    'running_acc': 0.5315625071525574,
#    'running_loss': 1.558319330215454}),
#  ((1565, None),
#   {'acc': 0.5361486673355103,
#    'loss': 1.5240708589553833,
#    'running_acc': 0.5287500023841858,
#    'running_loss': 1.538155436515808}),
#  ((1565, None),
#   {'acc': 0.5435881018638611,
#    'loss': 1.4989995956420898,
#    'running_acc': 0.5546875,
#    'running_loss': 1.4697984457015991}),
#  ((1565, None),
#   {'acc': 0.5481865406036377,
#    'loss': 1.4792041778564453,
#    'running_acc': 0.5520312190055847,
#    'running_loss': 1.4723325967788696}),
#  ((1565, None),
#   {'acc': 0.5524455308914185,
#    'loss': 1.4650359153747559,
#    'running_acc': 0.5537499785423279,
#    'running_loss': 1.4622275829315186}),
#  ((1565, None),
#   {'acc': 0.5541980266571045,
#    'loss': 1.4551677703857422,
#    'running_acc': 0.5529687404632568,
#    'running_loss': 1.4670062065124512}),
#  ((1565, None),
#   {'acc': 0.5564248561859131,
#    'loss': 1.4502472877502441,
#    'running_acc': 0.5618749856948853,
#    'running_loss': 1.4405103921890259}),
#  ((1565, None),
#   {'acc': 0.5576980710029602,
#    'loss': 1.4455935955047607,
#    'running_acc': 0.5548437237739563,
#    'running_loss': 1.4679993391036987})]

# %% [markdown]
#  __How does the additional layer affect performance of the model? Provide your answer in the block below:__

# %% [markdown]
# YOUR ANSWER HERE
